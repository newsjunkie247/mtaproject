# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np

# %%
ridership = pd.read_csv('https://raw.githubusercontent.com/newsjunkie247/mtaproject/master/subway.csv',index_col=0, header=1, thousands=',')

# %%
#getting the ridership data into pandas and into a useable format

# %%
ridership.dtypes
# Out:
# Boro                 object
# 2007                float64
# 2008                float64
# 2009                float64
# 2010                float64
# 2011                float64
# 2012                float64
# 2013                float64
# 2012-2013 Change    float64
# Unnamed: 10          object
# 2013 Rank           float64
# Unnamed: 12         float64
# dtype: object

# %%
ridership
# Out:
#                                             Boro     2007     2008     2009  \
# Station (alphabetical by borough)
# The Bronx                                    NaN      NaN      NaN      NaN
# 138 St-Grand Concourse (4,5)                  Bx     2720     2926     2969
# 149 St-Grand Concourse (2,4,5)                Bx    10384    11395    12056
# 161 St-Yankee Stadium (B,D,4)                 Bx    24258    26511    26061
# 167 St (4)                                    Bx     8564     9125     9054
# 167 St (B,D)                                  Bx     8747     8913     8848
# 170 St (4)                                    Bx     7958     8661     8848
# 170 St (B,D)                                  Bx     6273     6421     6255
# 174 St (2,5)                                  Bx     6514     6876     6801
# 174-175 Sts (B,D)                             Bx     4669     4822     4603
# 176 St (4)                                    Bx     4606     5105     4312
# ...

# %%
ridership = ridership.dropna(axis=0, how='all', thresh=None, subset=None, inplace=False)

# %%
ridership = ridership.reset_index()

# %%
ridership
# Out:
#                Station (alphabetical by borough) Boro     2007     2008  \
# 0                  138 St-Grand Concourse (4,5)    Bx     2720     2926
# 1                149 St-Grand Concourse (2,4,5)    Bx    10384    11395
# 2                 161 St-Yankee Stadium (B,D,4)    Bx    24258    26511
# 3                                    167 St (4)    Bx     8564     9125
# 4                                  167 St (B,D)    Bx     8747     8913
# 5                                    170 St (4)    Bx     7958     8661
# 6                                  170 St (B,D)    Bx     6273     6421
# 7                                  174 St (2,5)    Bx     6514     6876
# 8                             174-175 Sts (B,D)    Bx     4669     4822
# 9                                    176 St (4)    Bx     4606     5105
# 10                            182-183 Sts (B,D)    Bx     4898     4747
# 11                                   183 St (4)    Bx     3371     5890
# ...

# %%
ridership = ridership.rename(columns = {'Unnamed: 10':'12/13 %'})

# %%
ridership = ridership.rename(columns = {'Unnamed: 12':'07/13 Change'})

# %%
ridership
# Out:
#                Station (alphabetical by borough) Boro     2007     2008  \
# 0                  138 St-Grand Concourse (4,5)    Bx     2720     2926
# 1                149 St-Grand Concourse (2,4,5)    Bx    10384    11395
# 2                 161 St-Yankee Stadium (B,D,4)    Bx    24258    26511
# 3                                    167 St (4)    Bx     8564     9125
# 4                                  167 St (B,D)    Bx     8747     8913
# 5                                    170 St (4)    Bx     7958     8661
# 6                                  170 St (B,D)    Bx     6273     6421
# 7                                  174 St (2,5)    Bx     6514     6876
# 8                             174-175 Sts (B,D)    Bx     4669     4822
# 9                                    176 St (4)    Bx     4606     5105
# 10                            182-183 Sts (B,D)    Bx     4898     4747
# 11                                   183 St (4)    Bx     3371     5890
# ...

# %%
ridership['07/13 Change'] = ridership['2013']-ridership['2007'] #calculating percentage growth for every station

# %%
ridership
# Out:
#                Station (alphabetical by borough) Boro     2007     2008  \
# 0                  138 St-Grand Concourse (4,5)    Bx     2720     2926
# 1                149 St-Grand Concourse (2,4,5)    Bx    10384    11395
# 2                 161 St-Yankee Stadium (B,D,4)    Bx    24258    26511
# 3                                    167 St (4)    Bx     8564     9125
# 4                                  167 St (B,D)    Bx     8747     8913
# 5                                    170 St (4)    Bx     7958     8661
# 6                                  170 St (B,D)    Bx     6273     6421
# 7                                  174 St (2,5)    Bx     6514     6876
# 8                             174-175 Sts (B,D)    Bx     4669     4822
# 9                                    176 St (4)    Bx     4606     5105
# 10                            182-183 Sts (B,D)    Bx     4898     4747
# 11                                   183 St (4)    Bx     3371     5890
# ...

# %%
ridership['7/13 %'] = (ridership['07/13 Change']/ridership['2007'])*100

# %%
ridership
# Out:
#                Station (alphabetical by borough) Boro     2007     2008  \
# 0                  138 St-Grand Concourse (4,5)    Bx     2720     2926
# 1                149 St-Grand Concourse (2,4,5)    Bx    10384    11395
# 2                 161 St-Yankee Stadium (B,D,4)    Bx    24258    26511
# 3                                    167 St (4)    Bx     8564     9125
# 4                                  167 St (B,D)    Bx     8747     8913
# 5                                    170 St (4)    Bx     7958     8661
# 6                                  170 St (B,D)    Bx     6273     6421
# 7                                  174 St (2,5)    Bx     6514     6876
# 8                             174-175 Sts (B,D)    Bx     4669     4822
# 9                                    176 St (4)    Bx     4606     5105
# 10                            182-183 Sts (B,D)    Bx     4898     4747
# 11                                   183 St (4)    Bx     3371     5890
# ...

# %%
ridership2 = ridership[:421] #removing the aggregate numbers

# %%
data = ridership.sort("7/13 %", ascending=False) #sorting by ridership percentage

# %%
ridership2.reindex()
# Out:
#                Station (alphabetical by borough) Boro   2007   2008   2009  \
# 0                  138 St-Grand Concourse (4,5)    Bx   2720   2926   2969
# 1                149 St-Grand Concourse (2,4,5)    Bx  10384  11395  12056
# 2                 161 St-Yankee Stadium (B,D,4)    Bx  24258  26511  26061
# 3                                    167 St (4)    Bx   8564   9125   9054
# 4                                  167 St (B,D)    Bx   8747   8913   8848
# 5                                    170 St (4)    Bx   7958   8661   8848
# 6                                  170 St (B,D)    Bx   6273   6421   6255
# 7                                  174 St (2,5)    Bx   6514   6876   6801
# 8                             174-175 Sts (B,D)    Bx   4669   4822   4603
# 9                                    176 St (4)    Bx   4606   5105   4312
# 10                            182-183 Sts (B,D)    Bx   4898   4747   4612
# ...

# %%
data.reindex()
# Out:
#        Station (alphabetical by borough) Boro   2007   2008   2009   2010  \
# 316                    Cortlandt St (R)     M      0      0    347   3361
# 374              Aqueduct Racetrack (A)     Q     58     60     52     61
# 375       Aqueduct-North Conduit Av (A)     Q    895    889    830    791
# 43                   Kingsbridge Rd (4)    Bx   5049   8980   9320   9754
# 11                           183 St (4)    Bx   3371   5890   5954   6071
# 397        Howard Beach-JFK Airport (A)     Q   2837   2966   2801   2667
# 224                         York St (F)     B   5131   5894   6077   6621
# 417          Vernon Blvd-Jackson Av (7)     Q   8019   9541   9607  10028
# 357                         39 Av (N,Q)     Q   2110   2269   2562   2833
# 183                       Morgan Av (L)     B   4633   5078   5269   6050
# 192                     New Lots Av (L)     B   3115   3520   3729   3961
# 333                       Rector St (1)     M   7386   8072   7983   8165
# ...

# %%
#trying to get the data into other forms

# %%
data = data.set_index(['Station (alphabetical by borough)', 'Boro'])

# %%
data.ix[:,0:7].groupby(by="2007")

# %%
data = ridership.ix[:,0:9].groupby(by="Station (alphabetical by borough)").sum().reset_index()

# %%
datax = ridership2.ix[:,0:9].groupby(by="Station (alphabetical by borough)").sum().reset_index()

# %%
datax = datax.set_index("Station (alphabetical by borough)")

# %%
data = data.set_index("Station (alphabetical by borough)")

# %%
datax.stack()
# Out:
# Station (alphabetical by borough)
# 1 Av (L)                           2007    17358
#                                    2008    19203
#                                    2009    20006
#                                    2010    21157
#                                    2011    22039
#                                    2012    22436
#                                    2013    23467
# 103 St (1)                         2007    13353
#                                    2008    13573
#                                    2009    13409
#                                    2010    12968
#                                    2011    13292
#                                    2012    13557
#                                    2013    13500
# 103 St (6)                         2007    13897
# ...
# Woodside-61 St (7)                 2013    16559
# York St (F)                        2007     5131
#                                    2008     5894
# ...

# %%
data.stack()
# Out:
# Station (alphabetical by borough)
# 1 Av (L)                           2007    17358
#                                    2008    19203
#                                    2009    20006
#                                    2010    21157
#                                    2011    22039
#                                    2012    22436
#                                    2013    23467
# 103 St (1)                         2007    13353
#                                    2008    13573
#                                    2009    13409
#                                    2010    12968
#                                    2011    13292
#                                    2012    13557
#                                    2013    13500
# 103 St (6)                         2007    13897
# ...
# Woodside-61 St (7)                 2013    16559
# York St (F)                        2007     5131
#                                    2008     5894
# ...

# %%
data2 = data.stack(0).reset_index()

# %%
datareset = datax.stack(0).reset_index()

# %%
datareset
# Out:
#      Station (alphabetical by borough) level_1      0
# 0                            1 Av (L)     2007  17358
# 1                            1 Av (L)     2008  19203
# 2                            1 Av (L)     2009  20006
# 3                            1 Av (L)     2010  21157
# 4                            1 Av (L)     2011  22039
# 5                            1 Av (L)     2012  22436
# 6                            1 Av (L)     2013  23467
# 7                          103 St (1)     2007  13353
# 8                          103 St (1)     2008  13573
# 9                          103 St (1)     2009  13409
# 10                         103 St (1)     2010  12968
# 11                         103 St (1)     2011  13292
# 12                         103 St (1)     2012  13557
# 13                         103 St (1)     2013  13500
# 14                         103 St (6)     2007  13897
# 15                         103 St (6)     2008  14500
# ...

# %%
data2
# Out:
#      Station (alphabetical by borough) level_1      0
# 0                            1 Av (L)     2007  17358
# 1                            1 Av (L)     2008  19203
# 2                            1 Av (L)     2009  20006
# 3                            1 Av (L)     2010  21157
# 4                            1 Av (L)     2011  22039
# 5                            1 Av (L)     2012  22436
# 6                            1 Av (L)     2013  23467
# 7                          103 St (1)     2007  13353
# 8                          103 St (1)     2008  13573
# 9                          103 St (1)     2009  13409
# 10                         103 St (1)     2010  12968
# 11                         103 St (1)     2011  13292
# 12                         103 St (1)     2012  13557
# 13                         103 St (1)     2013  13500
# 14                         103 St (6)     2007  13897
# 15                         103 St (6)     2008  14500
# ...

# %%
data2 = data2.rename(columns = {'level_1':'year'})

# %%
datareset = datareset.rename(columns = {'level_1':'year'})

# %%
data2 = data2.rename(columns = {'Station (alphabetical by borough)':'stations'})

# %%
datareset = datareset.rename(columns = {'Station (alphabetical by borough)':'stations'})

# %%
data2 = data2.rename(columns = {0:'ridership'})

# %%
datareset = datareset.rename(columns = {0:'ridership'})

# %%
data2
# Out:
#                       stations  year  ridership
# 0                    1 Av (L)   2007      17358
# 1                    1 Av (L)   2008      19203
# 2                    1 Av (L)   2009      20006
# 3                    1 Av (L)   2010      21157
# 4                    1 Av (L)   2011      22039
# 5                    1 Av (L)   2012      22436
# 6                    1 Av (L)   2013      23467
# 7                  103 St (1)   2007      13353
# 8                  103 St (1)   2008      13573
# 9                  103 St (1)   2009      13409
# 10                 103 St (1)   2010      12968
# 11                 103 St (1)   2011      13292
# 12                 103 St (1)   2012      13557
# 13                 103 St (1)   2013      13500
# 14                 103 St (6)   2007      13897
# 15                 103 St (6)   2008      14500
# 16                 103 St (6)   2009      14663
# 17                 103 St (6)   2010      15210
# 18                 103 St (6)   2011      15673
# ...

# %%
datareset
# Out:
#                       stations  year  ridership
# 0                    1 Av (L)   2007      17358
# 1                    1 Av (L)   2008      19203
# 2                    1 Av (L)   2009      20006
# 3                    1 Av (L)   2010      21157
# 4                    1 Av (L)   2011      22039
# 5                    1 Av (L)   2012      22436
# 6                    1 Av (L)   2013      23467
# 7                  103 St (1)   2007      13353
# 8                  103 St (1)   2008      13573
# 9                  103 St (1)   2009      13409
# 10                 103 St (1)   2010      12968
# 11                 103 St (1)   2011      13292
# 12                 103 St (1)   2012      13557
# 13                 103 St (1)   2013      13500
# 14                 103 St (6)   2007      13897
# 15                 103 St (6)   2008      14500
# 16                 103 St (6)   2009      14663
# 17                 103 St (6)   2010      15210
# 18                 103 St (6)   2011      15673
# ...

# %%
datareset.groupby(["year", "stations"]).sum()
# Out:
#                                                       ridership
# year stations
# 2007 1 Av (L)                                             17358
#      103 St (1)                                           13353
#      103 St (6)                                           13897
#      103 St (B,C)                                          4778
#      103 St-Corona Plaza (7)                              16352
#      104 St (A)                                            1808
#      104 St (J,Z)                                          2388
#      110 St (6)                                           10973
#      111 St (7)                                            9725
#      111 St (A)                                            2678
#      111 St (J)                                            2588
#      116 St (2,3)                                          9522
#      116 St (6)                                           13994
# ...

# %%
datareset.groupby(["year", "stations"]).sum().plot(style=['o']) #ridership by year by station

# %%
datareset.groupby(["stations", "year"]).sum().sort("ridership", ascending=False)
# Out:
#                                                       ridership
# stations                                        year
# Times Sq-42 St (N,Q,R,S,1,2,3,7)/42 St (A,C,E)  2013     197696
#                                                 2012     195464
#                                                 2008     189506
#                                                 2011     189426
#                                                 2010     182170
#                                                 2007     181992
#                                                 2009     181224
# Grand Central-42 St (S,4,5,6,7)                 2013     153861
#                                                 2008     153747
#                                                 2012     150266
#                                                 2007     149224
#                                                 2011     147644
#                                                 2009     144904
# ...

# %%
datareset.groupby(["stations", "year"]).sum()
# Out:
#                                ridership
# stations                 year
# 1 Av (L)                 2007      17358
#                          2008      19203
#                          2009      20006
#                          2010      21157
#                          2011      22039
#                          2012      22436
#                          2013      23467
# 103 St (1)               2007      13353
#                          2008      13573
#                          2009      13409
#                          2010      12968
#                          2011      13292
#                          2012      13557
#                          2013      13500
# 103 St (6)               2007      13897
#                          2008      14500
#                          2009      14663
#                          2010      15210
#                          2011      15673
#                          2012      15721
#                          2013      16189
# ...

# %%
plt.figure(); datareset.groupby(["stations", "year"]).sum().plot(style=['o']) #plotting by station, by year,

# %%
 plt.figure(); datareset.groupby(["stations", "year"]).sum()[:200].plot(kind="bar") #plotting by station, by year,

# %%
ridership2 = ridership2.set_index("Station (alphabetical by borough)")

# %%
ridership2.sort("7/13 %", ascending=False)[["7/13 %"]][:30].plot(kind="bar") #ridership increasae by percent

# %%
ridership2.sort("7/13 %", ascending=True)[["7/13 %"]][:30].plot(kind="bar") #ridership increasae by percent

# %%
datareset.groupby(["stations"]).mean().sort("ridership", ascending=False)[:50].plot(kind="bar") #average over all years, highest

# %%
datareset.groupby(["stations"]).mean().sort("ridership", ascending=True)[:50].plot(kind="bar") #average over all years, lowest

# %%
ridership2 = ridership2.reset_index()

# %%
ridership2 = ridership2.rename(columns = {'Station (alphabetical by borough)':'stations'})

# %%
ridership2

# %%
import re
ridership2["lines"]= ridership2['stations'].str.extract('(\(.+)') #putting lines in a separate column

# %%
ridership2['stations'] = ridership2["stations"].str.replace('(\(.+)', '', case=False)

# %%
ridership2["lines"] = ridership2["lines"].str.replace('(\()', '', case=False)

# %%
ridership2["lines"] = ridership2["lines"].str.replace('(\))', '', case=False)

# %%
ridership2["lines"] = ridership2["lines"].str.replace('(\,)', '', case=False)

# %%
ridership2 = ridership2.set_index(["lines", "stations"], append=True)

# %%
ridership2 = ridership2.reset_index().sort("stations", ascending=True)

# %%
ridership2=ridership2.drop("level_0",1)

# %%
#importing stops with latitude and longtitude 
stops = pd.read_csv('https://raw.githubusercontent.com/newsjunkie247/mtaproject/master/stops.csv', header=None)

# %%
stops = stops[1:1863]

# %%
#cleaning pup the data, removing the double rows, renaming columns, creating an index

# %%
stops = stops[[2,3,4,16]]

# %%
stops = stops.drop_duplicates() #removing some double rows

# %%
stops = stops.sort(2, ascending=True)

# %%
stops = stops.drop_duplicates(subset=[2,16])

# %%
stops = stops.rename(columns = {2:'stations'})

# %%
stops = stops.rename(columns = {16:'lines'})

# %%
stops1 = stops.reset_index().sort("stations", ascending=True)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=\d)rd)', ' ', case=False)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=\d)th)', ' ', case=False)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=\d)nd)', ' ', case=False)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=\d)st)', ' ', case=True)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=St)-\w+\s\w+\s\w+)',"", case=True)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=St)-[^0-9]+\s[^0-9]+)',"", case=True)

# %%
stops1["stations"] = stops1["stations"].str.replace('(-\d+\sSt$)','', case=True)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=St-)\d+\s)','', case=False)

# %%
stops1["stations"] = stops1["stations"].str.replace('((?<=St)-\sSt)','', case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Av)',"Ave", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Avee)',"Ave", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Sq)',"Square", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Sq)',"Square", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Wakefield-241St25)',"Wakefield-241St2", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(149 St-3 Ave\s)',"3Ave-149St", case=True)

# %%
ridership3['stations'] = ridership3['stations'].str.replace('(Squareuare)',"Square", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Squareuare)',"Square", case=True)

# %%
stops1["stations"] = stops5["stations"].str.replace('(\s)',"", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(149St-3Ave)',"3Ave-149St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(138St-3Ave)',"3Ave-138St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(EastTremontAve-WestFarmsSq)',"WestFarmsSq-EastTremontAve", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(90StElmhurst)',"90St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(BlissSt-46St)',"46St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(FiskAve-69St)',"69St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(HuntersPoint)',"HuntersPointAve", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(LincolnAve-52St)',"52St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(LowerySt-40St)',"40St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(RawsonSt-33St)',"33St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(BayParkway-22Ave)',"BayParkway", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(30Ave-GrandAve)',"30Ave", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(36Ave-WashingtonAve)',"36Ave", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(R1)',"1R", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(eFMR)',"EFMR", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(HuntersPointAveAve)',"HuntersPointAve", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(DyckmanSt-200St)',"DyckmanSt", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(ACJZ2345)',"AC", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(JaySt-BoroughHall)',"JaySt-MetroTech", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(BroadwayJunction-EastNewYork)',"BroadwayJunction", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(ForestParkway-85St)',"85St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Kosciusko)',"Kosciuszko", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(EldertsLane-75St)',"75St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(39Ave-BeebeAve)',"39Ave", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(AstoriaBlvd-HoytAve)',"AstoriaBlvd", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Parkchester-East177St)',"Parkchester", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(AH)',"AS", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(81St-MuseumofNaturalHistory)',"81St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(YankeeStadium-161S)',"161St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(NeptuneAve-VanSiclen)',"NeptuneAve", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(GL)',"LG", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(GS)',"S", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(JZ456)',"456JZ", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(S2345)',"2345S", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(161Stt)',"161St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(NewkirkAve)',"NewkirkPlaza", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(NewkirkAve)',"NewkirkPlaza", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(45Rd-CourtHouseSquare)',"CourtSquare", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(ParsonsBlvd-ArcherAve-JamaicaCenter)',"JamaicaCenter-Parsons-Archer", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(\(\))',"", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Wakefield-241St25)',"Wakefield-241St2", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Beach105StH)',"Beach105StAS", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Beach90StH)',"Beach90StAS", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Beach98StH)',"Beach98StAS", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(RockawayPark-Beach116H)',"RockawayPark-Beach116StAS", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(FultonStAC)',"FultonStACJZ2345", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(BroadwayJunctionACJL)', "BroadwayJunctionACJLZ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Briarwood-VanWyckBlvdF)', "Briarwood-VanWyckBlvdEF", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(7AveF)',"7AveFG", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(ChurchAveF)',"ChurchAveFG", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(FortHamiltonParkwayF)',"FortHamiltonParkwayFG", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(Smith-9StFGR)',"Smith-9StFG", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(9StFGR)',"4AveFGR", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(AveHBQ)',"AveHQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(BeverlyRdBQ)',"BeverlyRdQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(AveJBQ)',"AveJQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(AveMBQ)',"AveMQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(AveUBQ)',"AveUQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(CortelyouRdBQ)',"CortelyouRdQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(NeckRdBQ)',"NeckRdQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(ParksideAveBQ)',"ParksideAveQ", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(NewkirkPlaza25)',"NewkirkAve25", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(36StNR)',"36StDNR", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(15StF)',"15StFG", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(RockawayPark-Beach116StH)',"RockawayPark-Beach116StAS", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(NereidAve1)',"238St1", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(BeverleyRd25)',"BeverlyRd25", case=True)

# %%
stops1['index'] = stops1['index'].str.replace('(BeverleyRoadQ)',"BeverleyRdQ", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('((UL))',"", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(RockawayPark-Beach116)', "RockawayPark-Beach116St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(238St)', "NereidAve", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Clinton&WashingtonAves)', "Clinton-WashingtonAves", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(ProspectPark-15St)', "15St", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Broadway-74St)', "74-Bway", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(163St-AmsterdamAve)', "163St", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(DN)',"ND", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(BNDQR2345)',"BDNQR2345", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(BQNDR2345)',"BNDQR2345", case=True)

# %%
stops1['stations'] = stops1['stations'].str.replace('(Beverly)', "Beverley", case=True)

# %%
stops1['lines'] = stops1['lines'].str.replace('(DN)',"ND", case=True)

# %%
stops = stops.set_index(["lines", "stations"])

# %%
stops1 = stops.reset_index().sort("stations", ascending=True)

# %%
stops1 = stops1.sort("stations", ascending=True)

# %%
stops2 = stops1.set_index(["lines", "stations"])

# %%
ridership3 = ridership2.sort("stations", ascending=True)

# %%
ridership3["lines"] = ridership3["lines"].str.replace('(/\d\sAv\s)', '', case=True)

# %%
ridership3["lines"] = ridership3["lines"].str.replace('(/\d+)', '', case=True)

# %%
ridership3["lines"] = ridership3["lines"].str.replace('(St\s)', '', case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(14 St-Union Sq)',"Union Square", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Times Sq-42 St)',"Times Square-42 St", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(NQRS1237 ACE)',"ACENQRS1237", case=True)

# %%
ridership3["stations"] = ridership3["stations"].str.replace('((?<=St)-\w+\s\w+\s\w+)',"", case=True)

# %%
ridership3["stations"] = ridership3["stations"].str.replace('((?<=St)-\w+\s\w+)',"", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Av)',"Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Pkwy)',"Parkway", case=True)

# %%
#/Whitehall

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Whitehall\s)',"", case=True)

# %%
#/Botanic Garden 
ridership3["lines"] = ridership3['lines'].str.replace('(/Botanic Garden\s)',"", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Chambers\s)',"", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Jackson Hts-Roosevelt Av\s)',"", case=True)

# %%
#/Metropolitan Av
ridership3["lines"] = ridership3['lines'].str.replace('(/Metropolitan Av\s)',"", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Central Park North-110 St)',"110 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(East 143 St\'s St)',"East 143 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Morrison Ave-Soundview)',"Morrison Ave-Soundview Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Sutter Ave-Rutland Rd)',"Sutter Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Crown Heights-Utica Ave)',"Utica Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Sq)',"Square", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Woodside-61 St)',"Woodside Ave-61 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Bushwick Ave-Aberdeen St)',"Bushwick Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Myrtle-Wyckoff Aves)',"Myrtle Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Middle Village-Metropolitan Ave)',"Metropolitan Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Dr)',"Drive", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Aveenue)',"Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Astoria-Ditmars Blvd)',"Ditmars Blvd", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(5 Ave-59 St)',"59 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Bay Ridge-95 St)',"95 St", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Borough Hall\s)',"", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Beach 67 St Sea)',"Beach 67 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Howard Beach-JFK Airport)',"Howard Beach", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Ozone Park-Lefferts Blvd)',"Lefferts Blvd", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Hoyt-Schermerhorn Sts)',"Hoyt&Schermerhorn", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Hwy)',"Highway", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/WTC)',"", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Park Place)',"", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Bleecker)',"", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(FM123L)',"FLM123", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(7EFMR)',"EFMR7", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(59StNQR)',"59StNQR", case=True)

# %%
ridership3["lines"] = ridership3['lines'].str.replace('(/Essex\s)',"", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(81 St History)',"81 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(47-50 Sts-Rockefeller Center)',"47-50StsRockefeller Center", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Lexington Ave-63 St)',"Lexington Ave", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Smith-9 Sts)',"Smith-9 St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Sutphin Blvd-Archer Ave-JFK Airport)',"SutphinBlvd-ArcherAve-JFK", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(21 St-Queensbridge)',"21St", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Placeaza)',"Plaza", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Placeace)',"Place", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Coney Island-Stillwell Ave)',"StillwellAve", case=True)

# %%
ridership3["stations"] = ridership3['stations'].str.replace('(Pl)',"Place", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(Kingston-ThroopAvesC)',"Kingston-ThroopAC", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(LibertyAveC)',"LibertyAveAC", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(RalphAveC)',"RalphAveAC", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(RockawayAveC)',"RockawayAveAC", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(ShepherdAveC)',"ShepherdAveAC", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(VanSiclenAveC)',"VanSiclenAveAC", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(FranklinAveCS)',"FranklinAveACS", case=True)

# %%
ridership3["index"] = ridership3['index'].str.replace('(59StNQR)',"59StNQR456", case=True)

# %%
ridership4 = ridership3.set_index(["lines", "stations"])

# %%
ridership3.dtypes
# Out:
# lines                object
# stations             object
# Boro                 object
# 2007                float64
# 2008                float64
# 2009                float64
# 2010                float64
# 2011                float64
# 2012                float64
# 2013                float64
# 2012-2013 Change     object
# 12/13 %              object
# 2013 Rank            object
# 07/13 Change        float64
# 7/13 %               object
# dtype: object

# %%
stops1.dtypes
# Out:
# lines       object
# stations    object
# 3           object
# 4           object
# dtype: object

# %%
stops1[[3, 4]] = stops1[[3, 4]].astype(float)

# %%
stops1.dtypes
# Out:
# lines        object
# stations     object
# 3           float64
# 4           float64
# dtype: object

# %%
stops2.dtypes
# Out:
# 3    float64
# 4    float64
# dtype: object

# %%
ridership3["stations"].fillna(ridership3['lines'], inplace=True)

# %%
#creating an index to join the two tables

# %%
ridership3["index"]=ridership3["stations"].map(str) + ridership3["lines"]

# %%
stops1["index"]=stops1["stations"]+ " " + stops1["lines"]

# %%
ridership5 = ridership3.set_index("index")

# %%
stops5 = stops1.set_index("index")

# %%
ridership5[3] =  np.nan

# %%
ridership5[4] = np.nan

# %%
ridership5.dtypes
# Out:
# index                object
# lines                object
# stations             object
# Boro                 object
# 2007                float64
# 2008                float64
# 2009                float64
# 2010                float64
# 2011                float64
# 2012                float64
# 2013                float64
# 2012-2013 Change     object
# 12/13 %              object
# 2013 Rank            object
# 07/13 Change        float64
# 7/13 %               object
# 3                   float64
# 4                   float64
# dtype: object

# %%
stops5.dtypes
# Out:
# index        object
# lines        object
# stations     object
# 3           float64
# 4           float64
# dtype: object

# %%
#removing whitespace

# %%
ridership3["index"] = ridership3["index"].str.replace('(\s)',"", case=True)

# %%
stops1["index"] = stops1["index"].str.replace('(\s)',"", case=True)

# %%
#merging the two tables together

# %%
subwaymerged = pd.merge(ridership3, stops1, on="index", how="outer")

# %%
subwaymerged
# Out:
#       lines_x     stations_x Boro    2007    2008    2009    2010    2011  \
# 0          L          1 Ave     M   17358   19203   20006   21157   22039
# 1          1         103 St     M   13353   13573   13409   12968   13292
# 2          6         103 St     M   13897   14500   14663   15210   15673
# 3         BC         103 St     M    4778    4961    4736    4782    4562
# 4          7         103 St     Q   16352   18021   17627   17751   18583
# 5          A         104 St     Q    1808    1827    1715    1693    1751
# 6         JZ         104 St     Q    2388    2509    2498    2527    2558
# 7          6         110 St     M   10973   11320   11425   11630   11836
# 8          7         111 St     Q    9725   10381   10366   10457   10593
# 9          A         111 St     Q    2678    2770    2666    2618    2711
# 10         J         111 St     Q    2588    2637    2607    2650    2683
# 11        23         116 St     M    9522    9968   10190   10227   10627
# ...

# %%
subwaymerged[subwaymerged["lines_y"].isnull()].sort("lines_x")
# Out:
#     lines_x     stations_x Boro  2007  2008  2009  2010  2011  2012  2013  \
# 235      1   Cortlandt St     M     0     0     0     0     0     0     0
#
#     2012-2013 Change 12/13 % 2013 Rank  07/13 Change 7/13 %         index  \
# 235              NAN     NAN       NAN             0    NAN  CortlandtSt1
#
#     lines_y stations_y   3   4
# 235     NaN        NaN NaN NaN

# %%
subwaymerged[subwaymerged["lines_x"].isnull()].sort("lines_y")
# Out:
#     lines_x stations_x Boro  2007  2008  2009  2010  2011  2012  2013  \
# 457     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 443     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 440     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 445     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 425     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 444     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 454     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 458     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 435     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 427     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 455     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 456     NaN        NaN  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
subwaymerged[:425]
# Out:
#           lines_x                            stations_x Boro    2007    2008  \
# 0              L                                 1 Ave     M   17358   19203
# 1              1                                103 St     M   13353   13573
# 2              6                                103 St     M   13897   14500
# 3             BC                                103 St     M    4778    4961
# 4              7                                103 St     Q   16352   18021
# 5              A                                104 St     Q    1808    1827
# 6             JZ                                104 St     Q    2388    2509
# 7              6                                110 St     M   10973   11320
# 8              7                                111 St     Q    9725   10381
# 9              A                                111 St     Q    2678    2770
# 10             J                                111 St     Q    2588    2637
# ...

# %%
ridership6 = subwaymerged[:425]

# %%
ridership8 = subwaymerged [:425]

# %%
ridership8
# Out:
#           lines_x                            stations_x Boro    2007    2008  \
# 0              L                                 1 Ave     M   17358   19203
# 1              1                                103 St     M   13353   13573
# 2              6                                103 St     M   13897   14500
# 3             BC                                103 St     M    4778    4961
# 4              7                                103 St     Q   16352   18021
# 5              A                                104 St     Q    1808    1827
# 6             JZ                                104 St     Q    2388    2509
# 7              6                                110 St     M   10973   11320
# 8              7                                111 St     Q    9725   10381
# 9              A                                111 St     Q    2678    2770
# 10             J                                111 St     Q    2588    2637
# ...

# %%
ridership8[ridership8['7/13 %']==Inf]
# Out:
#     lines_x     stations_x Boro  2007  2008  2009  2010  2011  2012  2013  \
# 236      R   Cortlandt St     M     0     0   347  3361  4745  6393  5497
#
#     2012-2013 Change 12/13 % 2013 Rank  07/13 Change 7/13 %         index  \
# 236             -896  -14.0%       271          5497    inf  CortlandtStR
#
#     lines_y   stations_y          3          4
# 236       R  CortlandtSt  40.710668 -74.011029

# %%
ridership7 = ridership7.set_index(["lines_x", "stations_x"])

# %%
ridership6["7/13 %"].value_counts()
# Out:
#  4.197512     2
#  10.272185    2
#  31.918343    2
# -1.777827     2
#  4.509165     1
#  12.958934    1
#  53.809627    1
#  0.293177     1
#  3.338140     1
# -4.719811     1
#  38.111888    1
# -12.702893    1
# -2.205882     1
# -15.435435    1
#  6.996454     1
# ...
# -7.023275     1
#  17.291979    1
#  5.468135     1
#  25.903308    1
# -68.500539    1
# -0.656797     1
#  39.509954    1
# -1.049348     1
# -0.748863     1
#  22.832995    1
# -40.573862    1
#  17.407266    1
#  9.770330     1
#  13.684114    1
#  10.102676    1
# Length: 421, dtype: int64

# %%
ridership7.dtypes
# Out:
# Boro                 object
# 2007                float64
# 2008                float64
# 2009                float64
# 2010                float64
# 2011                float64
# 2012                float64
# 2013                float64
# 2012-2013 Change     object
# 12/13 %              object
# 2013 Rank            object
# 07/13 Change        float64
# 7/13 %               object
# index                object
# lines_y              object
# stations_y           object
# 3                   float64
# 4                   float64
# dtype: object

# %%
ridership8 = ridership8.fillna(0)

# %%
ridership8["7/13 %"].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# ...
# 410    False
# 411    False
# 412    False
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# 418    False
# 419    False
# 420    False
# 421    False
# 422    False
# 423    False
# 424    False
# Name: 7/13 %, Length: 425, dtype: bool

# %%
ridership8.fillna({"NAN":"0"}).sort("12/13 %", ascending=False)
# Out:
#       lines_x                   stations_x Boro    2007    2008    2009  \
# 151        A           Aqueduct Racetrack     Q      58      60      52
# 235        1                 Cortlandt St     M       0       0       0
# 389       FG                   Smith-9 St     B    4097    4464    4579
# 413       FQ                    West 8 St     B    2146    2333    2302
# 188       23                    Bergen St     B    3946    4033    4015
# 49         N                       18 Ave     B    4686    5077    5227
# 133       NR                         8 St     M   16443   16696   16303
# 370       NR                    Prince St     M   13849   14330   13834
# 214       FG                   Carroll St     B    9930   10051    9786
# 250        6                  East 143 St    Bx     931     899     831
# 166        N                        Ave U     B    3197    3537    3871
# 196       AS                Broad Channel     Q     351     360     325
# ...

# %%
ridership8[ridership8["7/13 %"]==0]
# Out:
#     lines_x     stations_x Boro  2007  2008  2009  2010  2011  2012  2013  \
# 235      1   Cortlandt St     M     0     0     0     0     0     0     0
#
#      2012-2013 Change 12/13 %  2013 Rank  07/13 Change  7/13 %         index  \
# 235                 0       0          0             0       0  CortlandtSt1
#
#     lines_y stations_y  3  4
# 235       0          0  0  0

# %%
ridership8 = ridership8.replace(r'NAN', 0, regex=True)

# %%
ridership8 = ridership8.replace(r'inf', 1484, regex=True)

# %%
ridership8.sort("7/13 %", ascending=False)
# Out:
#     lines_x                   stations_x Boro   2007   2008   2009   2010  \
# 236      R                 Cortlandt St     M      0      0    347   3361
# 151      A           Aqueduct Racetrack     Q     58     60     52     61
# 152      A   Aqueduct-North Conduit Ave     Q    895    889    830    791
# 315      4               Kingsbridge Rd    Bx   5049   8980   9320   9754
# 54       4                       183 St    Bx   3371   5890   5954   6071
# 296      A                 Howard Beach     Q   2837   2966   2801   2667
# 423      F                      York St     B   5131   5894   6077   6621
# 408      7      Vernon Blvd-Jackson Ave     Q   8019   9541   9607  10028
# 91      NQ                       39 Ave     Q   2110   2269   2562   2833
# 336      L                   Morgan Ave     B   4633   5078   5269   6050
# 350      L                 New Lots Ave     B   3115   3520   3729   3961
# 377      1                    Rector St     M   7386   8072   7983   8165
# ...

# %%
ridership.dtypes
# Out:
# Station (alphabetical by borough)     object
# Boro                                  object
# 2007                                 float64
# 2008                                 float64
# 2009                                 float64
# 2010                                 float64
# 2011                                 float64
# 2012                                 float64
# 2013                                 float64
# 2012-2013 Change                     float64
# 12/13 %                               object
# 2013 Rank                            float64
# 07/13 Change                         float64
# 7/13 %                               float64
# dtype: object

# %%
stops.dtypes
# Out:
# stop_lat    float64
# stop_lon    float64
# dtype: object

# %%
#Running Kmeans on the increase from 2007 to 2013

from sklearn.cluster import KMeans
km = KMeans(n_clusters=4)
km.fit(ridership8[["7/13 %"]])
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=4, n_init=10,
#     n_jobs=1, precompute_distances=True, random_state=None, tol=0.0001,
#     verbose=0)

# %%
km.labels_[:10]
# Out:
# array([3, 0, 3, 0, 3, 0, 0, 0, 0, 0], dtype=int32)

# %%
ridership8["k-means label"] = km.labels_

# %%
ridership8[ridership8["k-means label"] == 0]["7/13 %"].hist(bins=2)
ridership8[ridership8["k-means label"] == 1]["7/13 %"].hist(bins=2)
ridership8[ridership8["k-means label"] == 2]["7/13 %"].hist(bins=2)
ridership8[ridership8["k-means label"] == 3]["7/13 %"].hist(bins=2)

# %%
ridership8[ridership8["k-means label"] == 0]["7/13 %"].hist(bins=3)
ridership8[ridership8["k-means label"] == 1]["7/13 %"].hist(bins=3)
ridership8[ridership8["k-means label"] == 2]["7/13 %"].hist(bins=3)
ridership8[ridership8["k-means label"] == 3]["7/13 %"].hist(bins=3)

# %%
#some basic stats 
ridership8.groupby("k-means label")["7/13 %"].describe()
# Out:
# k-means label
# 0              count     285.000000
#                mean        1.862537
#                std        13.527726
#                min       -68.500539
#                25%         0.075165
#                50%         4.633016
#                75%         9.275788
#                max        14.772111
# 1              count       1.000000
#                mean     1484.000000
#                std              NaN
#                min      1484.000000
#                25%      1484.000000
#                50%      1484.000000
#                75%      1484.000000
#                max      1484.000000
# 2              count       1.000000
#                mean      850.000000
#                std              NaN
#                min       850.000000
#                25%       850.000000
#                50%       850.000000
#                75%       850.000000
#                max       850.000000
# 3              count     138.000000
# ...

# %%
ridership8["7/13 %"].describe()
# Out:
# count     425.000000
# mean       16.141798
# std        84.373853
# min       -68.500539
# 25%         2.558423
# 50%         9.173747
# 75%        18.612910
# max      1484.000000
# dtype: float64

# %%
ridership8["7/13 %"].median()
# Out:
# 9.173747075483314

# %%
ridership2.to_csv("ridership2.csv") #printing  to csv

# %%
# !ls
# Out:
# 05 boolean_practice.ipynb
# 06_vectors_films_and_text.ipynb
# 07%20Cluster%20All%20The%20Text%20Things.ipynb
# 1l4sTI1
# 1l4sTI1.1
# 1l4sTI1.2
# 1l4stl1
# 2013.txt
# 2014a.txt
# 2014b.txt
# anony.ipynb
# APIs.ipynb
# AV1611text
# AV1611text.zip
# baby_names
# basics.ipynb
# capitalwords2.json
# capitalwords3.json
# capitalwordsaugust.json
# capitalwords.json
# censushomeworka.ipynb
# censushomeworkb.ipynb
# Census Homework .ipynb
# census.ipynb
# Class%20Setup.ipynb
# Congressional Record NLTK.ipynb
# convote_v1.1
# convote_v1.1.tar.gz
# convote_v1.tar.gz
# Curl.ipynb
# Data and Databases Homework Assignment 2.ipynb
# datahomework
# datahomework5.ipynb
# datahomework6.ipynb
# datahomework.ipynb
# document_clustering.ipynb
# dogs.csv
# Dogs.ipynb
# earthquake.ipynb
# enronsubjects.txt
# Facebookredone.ipynb
# facebookstudy
# facebookstudy.ipynb
# financialtimes.ipynb
# get_baby_names_data.ipynb
# Hello World.ipynb
# HMXPC13_DI_v2_5-14-14.csv
# Homework%20-%2005%20KMeans.ipynb
# ...

# %%
data6 = data.T.reset_index().set_index("index")

# %%
data6.columns = data6.columns.get_level_values(0)

# %%
data6.reset_index(level=0, inplace=True)

# %%
data6.T.columns = data6.T.columns.get_level_values(0)

# %%
data7 = data.T.reset_index()

# %%
data7 = data7.rename(columns = {'index':'year'})

# %%
data7.reset_index(drop=True).unstack()
# Out:
# Station (alphabetical by borough)
# year                               0     2007
#                                    1     2008
#                                    2     2009
#                                    3     2010
#                                    4     2011
#                                    5     2012
#                                    6     2013
# 1 Av (L)                           0    17358
#                                    1    19203
#                                    2    20006
#                                    3    21157
#                                    4    22039
#                                    5    22436
#                                    6    23467
# 103 St (1)                         0    13353
# ...
# Woodside-61 St (7)                 6    16559
# York St (F)                        0     5131
#                                    1     5894
#                                    2     6077
# ...

# %%
data7.set_index("year")
# Out:
# Station (alphabetical by borough)  1 Av (L)   103 St (1)   103 St (6)   \
# year
# 2007                                   17358        13353        13897
# 2008                                   19203        13573        14500
# 2009                                   20006        13409        14663
# 2010                                   21157        12968        15210
# 2011                                   22039        13292        15673
# 2012                                   22436        13557        15721
# 2013                                   23467        13500        16189
#
# Station (alphabetical by borough)  103 St (B,C)   103 St-Corona Plaza (7)   \
# year
# 2007                                        4778                     16352
# 2008                                        4961                     18021
# 2009                                        4736                     17627
# 2010                                        4782                     17751
# ...

# %%
data3 = ridership.sort("7/13 %", ascending=False)

# %%
data4 = data3[0:20].ix[:,0:9]

# %%
data4 = data4.set_index(["Station (alphabetical by borough)", "Boro"])

# %%
#ridership increase over the years (top 20 with the most increase

# %%
fig, ax = subplots()
data4.T.plot(ax=ax, legend=False)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
fig.savefig('results.png', bbox_inches='tight')
